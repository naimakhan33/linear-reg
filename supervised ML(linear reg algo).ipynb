# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Corrected file path (use raw string or double backslashes)
dataset = pd.read_csv(r"C:\Users\Ahsan\Downloads\cgpa_package_only.csv")

# Display the first 3 rows
dataset.head(3)
# Out:
#    CGPA  Package (LPA)
# 0   3.8             12
# 1   3.2              8
# 2   3.5             10

# %%
sns.scatterplot(x="CGPA",y="Package (LPA)",data=dataset)
plt.show()

# %%
dataset.isnull()
# Out:
#     CGPA  Package (LPA)
# 0  False          False
# 1  False          False
# 2  False          False
# 3  False          False
# 4  False          False

# %%
x = dataset[["CGPA"]]
y = dataset["Package (LPA)"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train, y_train)*100
# Out:
# 92.57142857142865

# %%
lr.predict([[3.8]])
# Out:
# C:\Users\Ahsan\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12.65])
